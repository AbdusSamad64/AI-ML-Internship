# %% [markdown]
# #**Abdus Samad (DHC-474)**
# #**Task 3**
# #Auto Tagging Support Tickets Using LLM

# %%
# !pip install -q transformers sentence-transformers scikit-learn datasets pandas joblib

# %% [markdown]
# # -------------------------
# # 1) IMPORTS
# # -------------------------

# %%
import pandas as pd
import numpy as np
import torch
from datasets import load_dataset
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import f1_score, accuracy_score
import joblib

# %% [markdown]
# # -------------------------
# # 2) LOAD DATASET
# # -------------------------

# %%
print("Loading dataset from Hugging Face...")
ds = load_dataset("Tobi-Bueck/customer-support-tickets")

df = pd.DataFrame(ds["train"])
print("Dataset Preview:")
display(df.head())

# Combine subject + body as text
df["text"] = df["subject"].fillna("") + " " + df["body"].fillna("")

# Collect tags from tag_1 ... tag_8 columns
tag_cols = [c for c in df.columns if c.startswith("tag_")]
df["tag_list"] = df[tag_cols].values.tolist()

# Clean None values
df["tag_list"] = df["tag_list"].apply(lambda tags: [t.lower() for t in tags if t not in [None, "None", "nan"]])

print(f"Total tickets: {len(df)}")
print("Sample tags:", df["tag_list"].head())
print("Unique tags:", sorted({t for tags in df.tag_list for t in tags}))
# Out:
# Loading dataset from Hugging Face...
# Dataset Preview:
#                                              subject  \
# 0                    Wesentlicher Sicherheitsvorfall
# 1                                 Account Disruption
# 2  Query About Smart Home System Integration Feat...
# 3                  Inquiry Regarding Invoice Details
# 4  Question About Marketing Agency Software Compa...
#
#                                                 body  \
# 0  Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1  Dear Customer Support Team,\n\nI am writing to...
# 2  Dear Customer Support Team,\n\nI hope this mes...
# 3  Dear Customer Support Team,\n\nI hope this mes...
# 4  Dear Support Team,\n\nI hope this message reac...
#
#                                               answer      type  \
# 0  Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1  Thank you for reaching out, <name>. We are awa...  Incident
# 2  Thank you for your inquiry. Our products suppo...   Request
# 3  We appreciate you reaching out with your billi...   Request
# 4  Thank you for your inquiry. Our product suppor...   Problem
#
#                    queue priority language  version     tag_1       tag_2  \
# 0      Technical Support     high       de     51.0  Security      Outage
# 1      Technical Support     high       en     51.0   Account  Disruption
# 2  Returns and Exchanges   medium       en     51.0   Product     Feature
# 3   Billing and Payments      low       en     51.0   Billing     Payment
# 4    Sales and Pre-Sales   medium       en     51.0   Product     Feature
#
#           tag_3          tag_4         tag_5 tag_6 tag_7 tag_8
# 0    Disruption    Data Breach          None  None  None  None
# 1        Outage             IT  Tech Support  None  None  None
# 2  Tech Support           None          None  None  None  None
# 3       Account  Documentation      Feedback  None  None  None
# 4      Feedback   Tech Support          None  None  None  None
# Total tickets: 48587
# Sample tags: 0          [security, outage, disruption, data breach]
# 1      [account, disruption, outage, it, tech support]
# 2                     [product, feature, tech support]
# 3    [billing, payment, account, documentation, fee...
# 4           [product, feature, feedback, tech support]
# Name: tag_list, dtype: object
# Unique tags: ['2019', 'abnormal', 'abonnement', 'abrechnungssystem', 'access', 'access control', 'access controls', 'access difficulty', 'access issue', 'access log', 'access management', 'access restriction', 'access-control', 'access_control', 'accesscontrol', 'accesscontrols', 'accessibility', 'accessmanagement', 'accessory', 'account', 'accounting', 'accrual', 'accrued', 'accuracy', 'action', 'actionteam', 'activation', 'activecampaign', 'ad', 'ad segment', 'ad spend', 'ad spending', 'adblocker', 'adblocking', 'adcontent', 'adcreative', 'add_ins', 'addins', 'address', 'adfatigue', 'adjustment', 'admin', 'adobe', 'adobe premiere pro', 'adobe sign', 'adobe_creative_cloud', 'adobeaftereffects', 'adobeaudition', 'adobecreativecloud', 'adobepremierepro', 'adobesign', 'adplacement', 'adtargeting', 'adtext', 'advanced tools', 'advertisement', 'advertising', 'advertising budget', 'advice', 'advisory', 'aes', 'aftereffects', 'agency', 'agile', 'ai', 'air', 'airtable', 'alarm', 'alert', 'algorithm', 'algorithm change', 'algorithm update', 'algorithms', 'alignment', 'allocation', 'alternative', 'alteryx', 'amount', 'analysis', 'analysis capability', 'analysis method', 'analysis platform', 'analysis,troubleshooting', 'analysistools', 'analytics', 'analytics platform', 'analyticsinconsistency', 'android', 'android studio', 'anleitung', 'annual plan', 'ansible', 'antivirus', 'apache hadoop', 'api', 'api integration', 'app', 'app issue', 'app update', 'application', 'application issue', 'appointment', 'approach', 'ar', 'architecture', 'artificialintelligence', 'asana', 'assessment', 'asset', 'assetrendering', 'assistance', 'assurance', 'attack', 'audience', 'audience engagement', 'audience insights', 'audience mismatch', 'audience reach', 'audience segment', 'audience segmentation', 'audience targeting', 'audiencereach', 'audio', 'audio editing', 'audiosettings', 'audit', 'auditing', 'audits', 'authentication', 'authorization', 'automation', 'availability', 'avast', 'avidprotools', 'awareness', 'aws', 'azure', 'backend', 'backlog', 'backup', 'backup,virus,security,breach,performance,disruption', 'bank', 'bank transfer', 'bank transfers', 'banktransfer', 'banktransfers', 'banküberweisung', 'behavior', 'benefit', 'benefits', 'best practice', 'best practices', 'bestpractices', 'betriebssystem', 'bi', 'billing', 'billing cycle', 'billing period', 'billing plan', 'billing,product,error,data analytics,breach', 'bitbucket', 'bitlocker', 'bitrate', 'blockchain', 'bluetooth', 'brand', 'brand awareness', 'brand campaigns', 'brand development', 'brand engagement', 'brand enhancement', 'brand expansion', 'brand growth', 'brand management', 'brand marketing', 'brand messaging', 'brand presence', 'brand promotion', 'brand recognition', 'brand strategy', 'brand visibility', 'brandexpansion', 'brandgrowth', 'branding', 'brandrecognition', 'breach', 'browser', 'browser cache', 'browser compatibility', 'browserproblem', 'budget', 'budget reallocation', 'budgetallocation', 'budgeting', 'bug', 'bulk purchase', 'bundle', 'bundles', 'business', 'business analysis', 'business development', 'business expansion', 'business growth', 'business improvement', 'business information', 'business objectives', 'business operation', 'business operations', 'business performance', 'business planning', 'business process', 'business strategy', 'businessdevelopment', 'businessintelligence', 'cable', 'cache', 'cache clear', 'cache clearing', 'cache issue', 'cache problem', 'caching', 'caching issue', 'calendar', 'calibration', 'call', 'callarrange', 'callback', 'callscheduling', 'callsetup', 'campagnenmanagement', 'campaign', 'campaign analysis', 'campaign delay', 'campaign effectiveness', 'campaign launch', 'campaign management', 'campaign optimization', 'campaign performance', 'campaign strategy', 'campaignanalysis', 'campaignmanagement', 'campaignparticipation', 'campaignperformance', 'campaigns', 'cancellation', 'capability', 'capacity', 'case study', 'casestudies', 'casest ...

# %% [markdown]
# # -------------------------
# # 3) PREPARE LABELS
# # -------------------------

# %%
unique_labels = sorted({t for tags in df.tag_list for t in tags})
mlb = MultiLabelBinarizer(classes=unique_labels)
Y = mlb.fit_transform(df["tag_list"])

texts = df["text"].tolist()

# %% [markdown]
# # -------------------------
# # 4) ZERO-SHOT CLASSIFIER
# # -------------------------

# %%
print("\nLoading zero-shot pipeline...")
zero_shot = pipeline("zero-shot-classification",
                     model="facebook/bart-large-mnli",
                     device=0 if torch.cuda.is_available() else -1)

def zero_shot_predict(text, candidate_labels, top_k=3):
    res = zero_shot(text, candidate_labels, multi_label=True)
    labels = res["labels"]
    scores = res["scores"]
    ranked = list(zip(labels, scores))
    return ranked[:top_k]

print("\nZero-shot demo:")
print(zero_shot_predict(texts[0], unique_labels, top_k=3))
# Out:
# Loading zero-shot pipeline...
# Device set to use cuda:0
# Zero-shot demo:
# [('infrastructure', 0.988297700881958), ('potential consequence', 0.980190634727478), ('alarm', 0.9800743460655212)]

# %% [markdown]
# # --------------------------------
# # 5) FEW-SHOT k-NN ON EMBEDDINGS
# # --------------------------------

# %%
print("\nLoading sentence-transformer embeddings...")
embed_model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = embed_model.encode(texts, convert_to_tensor=True, show_progress_bar=True)


support_texts, support_labels = [], []
for label in unique_labels:
    example = df[df["tag_list"].apply(lambda tags: label in tags)].head(1)
    if len(example) > 0:
        support_texts.append(example.iloc[0]["text"])
        support_labels.append(label)

support_embeddings = embed_model.encode(support_texts, convert_to_tensor=True)

def few_shot_predict(text, top_k=3):
    emb = embed_model.encode(text, convert_to_tensor=True)
    cos_scores = util.cos_sim(emb, support_embeddings)[0]
    label_scores = {support_labels[i]: float(cos_scores[i]) for i in range(len(support_labels))}
    ranked = sorted(label_scores.items(), key=lambda x: x[1], reverse=True)
    return ranked[:top_k]

print("\nFew-shot demo:")
print(few_shot_predict(texts[0], top_k=3))
# Out:
# Loading sentence-transformer embeddings...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/1519 [00:00<?, ?it/s]
# Few-shot demo:
# [('data breach', 1.0), ('disruption', 1.0), ('outage', 1.0)]

# %% [markdown]
# # ------------------------------------------
# # 6) SUPERVISED CLASSIFIER ON EMBEDDINGS
# # ------------------------------------------

# %%
print("\nTraining supervised classifier (Logistic Regression)...")

X_train, X_test, y_train, y_test = train_test_split(
    embeddings.cpu().numpy(), Y, test_size=0.2, random_state=42
)

clf = OneVsRestClassifier(LogisticRegression(max_iter=1000))
clf.fit(X_train, y_train)

joblib.dump({"clf": clf, "mlb": mlb, "embed_model": "all-MiniLM-L6-v2"}, "ticket_tagging_model.joblib")

y_pred = clf.predict(X_test)
f1_micro = f1_score(y_test, y_pred, average="micro")
f1_macro = f1_score(y_test, y_pred, average="macro")

print(f"Supervised Evaluation -> F1-micro: {f1_micro:.4f}, F1-macro: {f1_macro:.4f}")
# Out:
# Training supervised classifier (Logistic Regression)...
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 12 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 22 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 25 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 41 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 54 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 72 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 77 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 81 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 82 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 85 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 86 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 98 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 117 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 121 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 154 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 164 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 170 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 179 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 197 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 206 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 208 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 212 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 213 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 225 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 227 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 232 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 233 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 236 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 241 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 245 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 251 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 257 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 262 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 270 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 276 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 281 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 283 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 298 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 325 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 330 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 369 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 398 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 441 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 454 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 466 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 467 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 473 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 476 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 478 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 489 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 491 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 493 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 499 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 500 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 503 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 509 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 512 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 516 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 518 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 520 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 521 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 538 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 539 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 540 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 574 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 589 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 591 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 600 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 601 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 638 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 652 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 657 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 663 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 675 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 686 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 704 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 710 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 712 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 719 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 729 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 732 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 735 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 742 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 753 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 754 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 761 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 780 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 782 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 785 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 795 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 798 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 807 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 808 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 817 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 826 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 831 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 832 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 842 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 867 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 879 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 908 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 909 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 943 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 949 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 951 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1005 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1006 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1009 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1010 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1019 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1020 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1030 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1033 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1037 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1039 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1055 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1068 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1078 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1094 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1095 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1121 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1151 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1156 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1159 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1180 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1192 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1213 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1239 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1243 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1249 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1276 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1290 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1291 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1294 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1304 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1312 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1339 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1350 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1357 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1366 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1439 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1442 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1446 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1462 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1468 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1470 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1496 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1531 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1550 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1570 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1572 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1578 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1580 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1585 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1586 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1603 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1606 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1621 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1625 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1632 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1636 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1648 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1651 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1654 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1659 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1660 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1665 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1681 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1695 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1696 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1709 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1738 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1757 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1761 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1766 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1773 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1779 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1781 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1820 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1831 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1838 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1840 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1842 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1849 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1850 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1851 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1869 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1893 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1894 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1897 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1909 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1920 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1921 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1922 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1927 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1941 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1952 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1960 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1963 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1964 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 1975 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2013 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2038 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2047 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2070 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2076 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2081 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2101 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2107 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2121 is present in all training examples.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/multiclass.py:90: UserWarning: Label not 2122 is present in all training examples.
#   warnings.warn(
# Supervised Evaluation -> F1-micro: 0.6083, F1-macro: 0.0090
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # -------------------------
# # 7) COMPARISON ON SAMPLE
# # -------------------------

# %%
sample_text = "I cannot login to my account, password reset is not working."
print("\nSample Ticket:", sample_text)

print("Zero-shot:", zero_shot_predict(sample_text, unique_labels))
print("Few-shot:", few_shot_predict(sample_text))
emb = embed_model.encode(sample_text, convert_to_tensor=True).cpu().numpy().reshape(1, -1)
probas = clf.predict_proba(emb)[0]
sup_top = [mlb.classes_[i] for i in np.argsort(probas)[::-1][:3]]
print("Supervised (top-3):", sup_top)

print("\n✅ All steps completed. Model + predictions ready!")
# Out:
# Sample Ticket: I cannot login to my account, password reset is not working.
# Zero-shot: [('unsuccessful', 0.9992147088050842), ('technical difficulty', 0.998298704624176), ('concern', 0.9980844855308533)]
# Few-shot: [('unsuccessful', 0.6177732944488525), ('backlog', 0.5877218246459961), ('evening', 0.5877218246459961)]
# Supervised (top-3): ['login', 'account', 'technical']
#
# ✅ All steps completed. Model + predictions ready!
